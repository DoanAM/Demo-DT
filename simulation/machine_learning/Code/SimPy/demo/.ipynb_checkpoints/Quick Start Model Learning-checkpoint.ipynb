# %% [markdown]
# # Quick Start: Data Acquisition and Model Learning
# This is script illustrates different steps from retriving the data from database to training model and evaluation. The working flow is shown as following figure:
# ![1.png](attachment:1.png)
# <div class="alert alert-block alert-info"><b>Tip: </b>
#     <ul>
#         <li> In this demo, the data set for the workpiece "Versuchsteil Quadrant 7" is used as an example. The LSTM network is selected as the model for training and evaluation </li>
#         <li> Please run this notebook in the project python environment</li>
#     </ul>
# </div>

# %% [markdown]
# ## Dependencies

# %%
import os
os.chdir("../")
from util.data.DataHandler import DataHandler
from util.data.FeaturePreprocess import FeaturePreprocess
from mwCamSim import mwCamSim

from config import data_rootpath

import pandas as pd

import time
import json
import torch 
torch.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21228/281665457.py in <module>
#      12 import time
#      13 import json
# ---> 14 import torch
#      15 torch.__version__
#
# ModuleNotFoundError: No module named 'torch'
